# %% [markdown]
# # Chronicles of higher education job scraper
#
# Collecting all job advertisements for tenure-track for North American four-year institutions.
#
# - **[Query](https://jobs.chronicle.com/jobs/faculty-positions/north-america/tenured-tenured-track/)**
#
#
# Everytime you scrape:
#
# 1. Load in previous job advertisements
# 2. Scrape all the *new job advertisements*
# 3. De-duplicate if necessary
# 4. Output to DB/CSV

# %%
# Data manipulation libraries
import pandas as pd
import numpy as np
# Common webscraping libaries
from bs4 import BeautifulSoup as bs
from tqdm.notebook import tqdm
import requests
tqdm.pandas()

# %%
import re
import time

def parse_list_page_item(list_item):
    """
        Takes the list item HTML and parses out the four fields below into a list
    
    """
    title_tag = list_item.find("h3").find("a")
    job_title = title_tag.text
    job_url_suffix = title_tag['href'].strip()
    job_id = job_url_suffix.split("/")[2]
    job_url = f"https://jobs.chronicle.com{job_url_suffix}"
    diversity_job = False if list_item.find("p",attrs={"class":"ribbon"}) is None else True
    return [int(job_id),job_title,job_url,diversity_job]

def parse_list_page(url):
    """
        Returns the basic info from the jobs listing page
        
        || job id || job title || url || diversity job? 
    
    """
    time.sleep(1)
    r = requests.get(url,headers = {'User-Agent': 'Mozilla/5.0'})
    # The part of the webpage with the id tag "listing" contains all the job postings
    listing_page = bs(r.text).find("ul",attrs={"id":'listing'})
    # Parse out the ads
    list_items = listing_page.findAll("li",attrs={"id": re.compile("item-[0-9]+")})
    parsed_list_page = [parse_list_page_item(li) for li in list_items]
    return pd.DataFrame(parsed_list_page,columns=["Job ID","Job Title","Job URL","Diversity Job"]).set_index("Job ID")

# %%
# Get Job ID for most recent date posted which already exists
from glob import glob

most_recent_csv = sorted(glob("../data/*"))[::-1][0]
ls_df = pd.read_csv(most_recent_csv).sort_values("Date Posted",ascending=False)
already_scraped = set(ls_df['Job ID'])

# %%
url = "https://jobs.chronicle.com/jobs/faculty-positions/north-america/tenured-tenured-track/{}"

frames = []
job_ids = set()
page = 1
new_jobs = True
while new_jobs:
    print(page,end=" ")
    frame = parse_list_page(url.format(page))
    prev_job_ids = job_ids
    job_ids = set(frame.index)
    new_jobs = not (bool(job_ids.intersection(already_scraped)) or (prev_job_ids == job_ids))
    if bool(job_ids.intersection(already_scraped)): print(job_ids.intersection(already_scraped))
    frames.append(frame)
    page +=1

listing_df = pd.concat(frames)
listing_df = listing_df[~listing_df.index.isin(already_scraped)]
listing_df
# Out:
# 1 2 3 4 5 6 7 8 9 {367153, 367155, 367156}
#                                                 Job Title  \
# Job ID
# 369155  Professor & Director, School of Communication ...
# 363071  Lecturer or Clinical Assistant Professor of Nu...
# 367855  Chair - Georgia Tech/Emory Univ, Wallace H. Co...
# 370229   Professor of Linguistics--Editing and Publishing
# 370219             Marketing Faculty: Assistant Professor
# ...                                                   ...
# 367374                     Assistant Professor of Theatre
# 367371         Assistant Professor of Biological Sciences
# 367358                                Assistant Professor
# 367352        Tenure-Track Assistant Professor of Biology
# 367299  Assistant, Associate, Full Professor positions...
#
#                                                   Job URL  Diversity Job
# Job ID
# 369155  https://jobs.chronicle.com/job/369155/professo...           True
# 363071  https://jobs.chronicle.com/job/363071/lecturer...           True
# 367855  https://jobs.chronicle.com/job/367855/chair-ge...           True
# 370229  https://jobs.chronicle.com/job/370229/professo...          False
# 370219  https://jobs.chronicle.com/job/370219/marketin...          False
# ...                                                   ...            ...
# 367374  https://jobs.chronicle.com/job/367374/assistan...          False
# 367371  https://jobs.chronicle.com/job/367371/assistan...          False
# 367358  https://jobs.chronicle.com/job/367358/assistan...          False
# 367352  https://jobs.chronicle.com/job/367352/tenure-t...          False
# 367299  https://jobs.chronicle.com/job/367299/assistan...          False
#
# [180 rows x 3 columns]

# %%
def parse_details_page(url):
    """
        Parses the details page of a university
        
        || employer || location || salary || date posted || position_type (list) || description
    
    """
    time.sleep(0.25)
    r = requests.get(url,headers = {'User-Agent': 'Mozilla/5.0'})
    details_page = bs(r.text)
    # Get the job description
    description = details_page.find("div",attrs={"class":re.compile("[a-zA-Z0-9]*job-description*")}).get_text()
    
    details_block = details_page.find("dl",attrs={"class":"grid"})
    employer,location,salary,posted_date,position_type = None,None,None,None,None
    
    employer_html = details_block.find("div",attrs={"class": re.compile("[a-zA-Z0-9]*description__recruiter")})
    employer = None if employer_html is None else employer_html.find("dd").text.strip()
    
    location_html = details_block.find("div",attrs={"class": re.compile("[a-zA-Z0-9]*description__location")})
    location = None if location_html is None else location_html.find("dd").text.strip()
    
    salary_html = details_block.find("div",attrs={"class": re.compile("[a-zA-Z0-9]*description__salary")})
    salary = None if salary_html is None else salary_html.find("dd").text.strip()
    
    posted_date_html = details_block.find("div",attrs={"class": re.compile("[a-zA-Z0-9]*description__posted-date")})
    posted_date = None if posted_date_html is None else posted_date_html.find("dd").text.strip()
    
    position_type_html = details_block.find("div",attrs={"class": re.compile("[a-zA-Z0-9]*description__category-PositionType")})
    try:
        position_type = None if position_type_html is None else position_type_html.find("dd").findAll("a")
        position_type = [pt.text for pt in position_type]
    except:
        pass
    
    return employer,location,salary,posted_date,position_type,description

# %%
listing_df[['Employer',
            'Location',
            'Salary',
            'Date Posted',
            'position_type',
            'Description']] = listing_df.progress_apply(lambda row: parse_details_page(row['Job URL']),
                                                        axis=1,
                                                        result_type='expand')


listing_df["Date Posted"] = pd.to_datetime(listing_df["Date Posted"],infer_datetime_format=True)
# Out:
#   0%|          | 0/180 [00:00<?, ?it/s]

# %%
position_type = pd.DataFrame(listing_df['position_type'].values.tolist(),
                             index=listing_df.index).fillna(np.nan)
position_type = position_type.rename(columns = lambda x: (x/10)).add_prefix('Position Type ')
print("{}x{}".format(*listing_df.shape))
merged_df = pd.merge(listing_df,
                     position_type,
                     how="left",
                     left_index=True,
                     right_index=True)
print("{}x{}".format(*merged_df.shape))
merged_df = merged_df.drop("position_type",axis=1)
print("{}x{}".format(*merged_df.shape))
merged_df = merged_df.sort_values("Date Posted",ascending=False)
merged_df
# Out:
# 180x9
# 184x49
# 184x48
#                                                 Job Title  \
# Job ID
# 370229   Professor of Linguistics--Editing and Publishing
# 370099  Assistant Professor of Sociology and Criminal ...
# 369787  Professor, Associate Professor or Professor in...
# 369788  Assistant/Associate Professor of Environmental...
# 369789  Associate Professor of Landscape Architecture ...
# ...                                                   ...
# 367587  School of Public Policy - 2 Assistant Professo...
# 367588         Doctoral Faculty Position for CRNA Program
# 367593       Medical-Surgical Nursing Assistant Professor
# 367599      Full-Time Tenure-Track Faculty, School of Law
# 363071  Lecturer or Clinical Assistant Professor of Nu...
#
#                                                   Job URL  Diversity Job  \
# Job ID
# 370229  https://jobs.chronicle.com/job/370229/professo...          False
# 370099  https://jobs.chronicle.com/job/370099/assistan...          False
# 369787  https://jobs.chronicle.com/job/369787/professo...          False
# 369788  https://jobs.chronicle.com/job/369788/assistan...          False
# 369789  https://jobs.chronicle.com/job/369789/associat...          False
# ...                                                   ...            ...
# 367587  https://jobs.chronicle.com/job/367587/school-o...          False
# 367588  https://jobs.chronicle.com/job/367588/doctoral...          False
# 367593  https://jobs.chronicle.com/job/367593/medical-...          False
# 367599  https://jobs.chronicle.com/job/367599/full-tim...          False
# 363071  https://jobs.chronicle.com/job/363071/lecturer...           True
#
#                                                  Employer  \
# Job ID
# 370229                           Brigham Young University
# 370099                        Pacific Lutheran University
# 369787       Harvard University Graduate School of Design
# 369788       Harvard University Graduate School of Design
# 369789       Harvard University Graduate School of Design
# ...                                                   ...
# 367587                University of Massachusetts Amherst
# 367588  Providence Sacred Heart Medical Center/Gonzaga...
# 367593            Contra Costa Community College District
# 367599                           University of St. Thomas
# 363071                          Kennesaw State University
#
#                             Location                               Salary  \
# Job ID
# 370229           Utah, United States                 Salary Not specified
# 370099     Washington, United States              $55,000.00 - $57,000.00
# 369787  Massachusetts, United States                 Salary Not specified
# 369788  Massachusetts, United States                 Salary Not specified
# 369789  Massachusetts, United States                 Salary Not specified
# ...                              ...                                  ...
# 367587  Massachusetts, United States                 Salary Not specified
# 367588     Washington, United States  Salary Commensurate with experience
# 367593     California, United States                 Salary Not specified
# 367599      Minnesota, United States  Salary Commensurate with experience
# 363071        Georgia, United States                 Salary Not specified
#
#        Date Posted                                        Description  \
# Job ID
# 370229  2021-08-13  \nTo Apply: Click on the following link to acc...
# 370099  2021-08-13  \nGeneral Description: The Department\nof Soci...
# 369787  2021-08-13  \nThe Department of Urban Planning and Design ...
# 369788  2021-08-13  \nThe Harvard University Graduate School of De...
# 369789  2021-08-13  \nHarvard’s Department of Landscape Architectu...
# ...            ...                                                ...
# 367587  2021-08-06  \nJob Description\nThe UMass Amherst School of...
# 367588  2021-08-06  \nProvidence Sacred Heart Medical Center is se...
# 367593  2021-08-06  \n\nMedical-Surgical Nursing Assistant Profess...
# 367599  2021-08-06  \nThe University of St. Thomas School of Law (...
# 363071  2021-07-26  \nLecturer or Clinical Assistant\nProfessor of...
#
#         Position Type 0.0             Position Type 0.1  ...  \
# Job ID                                                   ...
# 370229  Faculty Positions                Communications  ...
# 370099  Faculty Positions  Social & Behavioral Sciences  ...
# 369787  Faculty Positions           Professional Fields  ...
# 369788  Faculty Positions           Professional Fields  ...
# 369789  Faculty Positions           Professional Fields  ...
# ...                   ...                           ...  ...
# 367587  Faculty Positions           Professional Fields  ...
# 367588  Faculty Positions             Health & Medicine  ...
# 367593  Faculty Positions             Health & Medicine  ...
# 367599  Faculty Positions           Professional Fields  ...
# 363071  Faculty Positions             Health & Medicine  ...
#
#        Position Type 3.0 Position Type 3.1 Position Type 3.2  \
# Job ID
# 370229               NaN               NaN               NaN
# 370099               NaN               NaN               NaN
# 369787               NaN               NaN               NaN
# 369788               NaN               NaN               NaN
# 369789               NaN               NaN               NaN
# ...                  ...               ...               ...
# 367587               NaN               NaN               NaN
# 367588               NaN               NaN               NaN
# 367593               NaN               NaN               NaN
# 367599               NaN               NaN               NaN
# 363071               NaN               NaN               NaN
#
#        Position Type 3.3 Position Type 3.4 Position Type 3.5  \
# Job ID
# 370229               NaN               NaN               NaN
# 370099               NaN               NaN               NaN
# 369787               NaN               NaN               NaN
# 369788               NaN               NaN               NaN
# 369789               NaN               NaN               NaN
# ...                  ...               ...               ...
# 367587               NaN               NaN               NaN
# 367588               NaN               NaN               NaN
# 367593               NaN               NaN               NaN
# 367599               NaN               NaN               NaN
# 363071               NaN               NaN               NaN
#
#        Position Type 3.6 Position Type 3.7 Position Type 3.8 Position Type 3.9
# Job ID
# 370229               NaN               NaN               NaN               NaN
# 370099               NaN               NaN               NaN               NaN
# 369787               NaN               NaN               NaN               NaN
# 369788               NaN               NaN               NaN               NaN
# 369789               NaN               NaN               NaN               NaN
# ...                  ...               ...               ...               ...
# 367587               NaN               NaN               NaN               NaN
# 367588               NaN               NaN               NaN               NaN
# 367593               NaN               NaN               NaN               NaN
# 367599               NaN               NaN               NaN               NaN
# 363071               NaN               NaN               NaN               NaN
#
# [184 rows x 48 columns]

# %%
from datetime import datetime

timestamp = datetime.now().strftime("%Y-%m-%d")
merged_df.to_csv(f"../data/{timestamp}-chronicles_of_higher_ed.csv")
