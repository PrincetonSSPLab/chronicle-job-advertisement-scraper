# %% [markdown]
# # Chronicles of higher education job scraper
#
# Collecting all job advertisements for tenure-track for North American four-year institutions.
#
# - **[Query](https://jobs.chronicle.com/jobs/faculty-positions/north-america/tenured-tenured-track/)**
#
#
# Everytime you scrape:
#
# 1. Load in previous job advertisements
# 2. Scrape all the *new job advertisements*
# 3. De-duplicate if necessary
# 4. Output to DB/CSV

# %%
# Data manipulation libraries
import pandas as pd
import numpy as np
# Common webscraping libaries
from bs4 import BeautifulSoup as bs
import requests

# %%
import re
import time

def parse_list_page_item(list_item):
    """
        Takes the list item HTML and parses out the four fields below into a list
    
    """
    title_tag = list_item.find("h3").find("a")
    job_title = title_tag.text
    job_url_suffix = title_tag['href'].strip()
    job_id = job_url_suffix.split("/")[2]
    job_url = f"https://jobs.chronicle.com{job_url_suffix}"
    diversity_job = False if list_item.find("p",attrs={"class":"ribbon"}) is None else True
    return [job_id,job_title,job_url,diversity_job]

def parse_list_page(url):
    """
        Returns the basic info from the jobs listing page
        
        || job id || job title || url || diversity job? 
    
    """
    time.sleep(1)
    r = requests.get(url,headers = {'User-Agent': 'Mozilla/5.0'})
    # The part of the webpage with the id tag "listing" contains all the job postings
    listing_page = bs(r.text).find("ul",attrs={"id":'listing'})
    # Parse out the ads
    list_items = listing_page.findAll("li",attrs={"id": re.compile("item-[0-9]+")})
    parsed_list_page = [parse_list_page_item(li) for li in list_items]
    return pd.DataFrame(parsed_list_page,columns=["Job ID","Job Title","Job URL","Diversity Job"]).set_index("Job ID")

# %%
url = "https://jobs.chronicle.com/jobs/faculty-positions/north-america/tenured-tenured-track/{}"
# TODO: build a function that scrapes all the details pages until we hit one that we've seen prior OR
# We hit the end (in which case the url just returns the final page)
frames = [parse_list_page(url.format(i)) for i in range(1,45)] 
listing_df = pd.concat(frames)
listing_df
# Out:
#                                                 Job Title  \
# Job ID
# 353930       Assistant Professor - Position Number 128670
# 350725  Full-Time, 9-month, tenure track position in t...
# 349332                    Dean, School of Dental Medicine
# 354649  Academic Advisor, Full-time Faculty (Northeast...
# 354648                                   Dean of Students
# ...                                                   ...
# 298881     Assistant or Associate Professor of Statistics
# 297349        Research Assistant Professor - Crop Science
# 287884  Assistant/Associate Professor of Health Psycho...
# 282211  Associate Dean for Graduate Studies and Facult...
# 282210   Associate Dean for Undergraduate Student Affairs
#
#                                                   Job URL  Diversity Job
# Job ID
# 353930  https://jobs.chronicle.com/job/353930/assistan...           True
# 350725  https://jobs.chronicle.com/job/350725/full-tim...           True
# 349332  https://jobs.chronicle.com/job/349332/dean-sch...           True
# 354649  https://jobs.chronicle.com/job/354649/academic...          False
# 354648  https://jobs.chronicle.com/job/354648/dean-of-...          False
# ...                                                   ...            ...
# 298881  https://jobs.chronicle.com/job/298881/assistan...          False
# 297349  https://jobs.chronicle.com/job/297349/research...          False
# 287884  https://jobs.chronicle.com/job/287884/assistan...          False
# 282211  https://jobs.chronicle.com/job/282211/associat...          False
# 282210  https://jobs.chronicle.com/job/282210/associat...          False
#
# [871 rows x 3 columns]

# %%
def parse_details_page(url):
    """
        Parses the details page of a university
        
        || employer || location || salary || date posted || position_type (list) || description
    
    """
    time.sleep(0.25)
    r = requests.get(url,headers = {'User-Agent': 'Mozilla/5.0'})
    details_page = bs(r.text)
    # Get the job description
    description = details_page.find("div",attrs={"class":re.compile("[a-zA-Z0-9]*job-description*")}).get_text()
    
    details_block = details_page.find("dl",attrs={"class":"grid"})
    employer,location,salary,posted_date,position_type = None,None,None,None,None
    
    employer_html = details_block.find("div",attrs={"class": re.compile("[a-zA-Z0-9]*description__recruiter")})
    employer = None if employer_html is None else employer_html.find("dd").text.strip()
    
    location_html = details_block.find("div",attrs={"class": re.compile("[a-zA-Z0-9]*description__location")})
    location = None if location_html is None else location_html.find("dd").text.strip()
    
    salary_html = details_block.find("div",attrs={"class": re.compile("[a-zA-Z0-9]*description__salary")})
    salary = None if salary_html is None else salary_html.find("dd").text.strip()
    
    posted_date_html = details_block.find("div",attrs={"class": re.compile("[a-zA-Z0-9]*description__posted-date")})
    posted_date = None if posted_date_html is None else posted_date_html.find("dd").text.strip()
    
    position_type_html = details_block.find("div",attrs={"class": re.compile("[a-zA-Z0-9]*description__category-PositionType")})
    try:
        position_type = None if position_type_html is None else position_type_html.find("dd").findAll("a")
        position_type = [pt.text for pt in position_type]
    except:
        pass
    
    return employer,location,salary,posted_date,position_type,description

# %%
listing_df[['Employer',
            'Location',
            'Salary',
            'Date Posted',
            'position_type',
            'Description']] = listing_df.apply(lambda row: parse_details_page(row['Job URL']),
                                               axis=1, 
                                               result_type='expand')


listing_df["Date Posted"] = pd.to_datetime(listing_df["Date Posted"],infer_datetime_format=True)

# %%
position_type = pd.DataFrame(listing_df['position_type'].values.tolist(),
                             index=listing_df.index).fillna(np.nan)
position_type = position_type.rename(columns = lambda x: (x/10)).add_prefix('Position Type ')
print("{}x{}".format(*listing_df.shape))
merged_df = pd.merge(listing_df,
                     position_type,
                     how="left",
                     left_index=True,
                     right_index=True)
print("{}x{}".format(*merged_df.shape))
merged_df = merged_df.drop("position_type",axis=1)
print("{}x{}".format(*merged_df.shape))
merged_df = merged_df.sort_values("Date Posted",ascending=False)
merged_df
# Out:
# 871x9
# 905x29
# 905x28
#                                                 Job Title  \
# Job ID
# 354649  Academic Advisor, Full-time Faculty (Northeast...
# 354648                                   Dean of Students
# 354561                  Instructor, Developmental English
# 354411  Assistant or Associate Professor Tenure Track ...
# 354486  Assistant or Associate Professor of Management...
# ...                                                   ...
# 282210   Associate Dean for Undergraduate Student Affairs
# 282211  Associate Dean for Graduate Studies and Facult...
# 282211  Associate Dean for Graduate Studies and Facult...
# 282211  Associate Dean for Graduate Studies and Facult...
# 282210   Associate Dean for Undergraduate Student Affairs
#
#                                                   Job URL  Diversity Job  \
# Job ID
# 354649  https://jobs.chronicle.com/job/354649/academic...          False
# 354648  https://jobs.chronicle.com/job/354648/dean-of-...          False
# 354561  https://jobs.chronicle.com/job/354561/instruct...          False
# 354411  https://jobs.chronicle.com/job/354411/assistan...          False
# 354486  https://jobs.chronicle.com/job/354486/assistan...          False
# ...                                                   ...            ...
# 282210  https://jobs.chronicle.com/job/282210/associat...          False
# 282211  https://jobs.chronicle.com/job/282211/associat...          False
# 282211  https://jobs.chronicle.com/job/282211/associat...          False
# 282211  https://jobs.chronicle.com/job/282211/associat...          False
# 282210  https://jobs.chronicle.com/job/282210/associat...          False
#
#                                                  Employer  \
# Job ID
# 354649                  Community College of Philadelphia
# 354648                  Community College of Philadelphia
# 354561                             Weber State University
# 354411                           University of Montevallo
# 354486                       SMU / Cox School of Business
# ...                                                   ...
# 282210  North Carolina Agricultural and Technical Stat...
# 282211  North Carolina Agricultural and Technical Stat...
# 282211  North Carolina Agricultural and Technical Stat...
# 282211  North Carolina Agricultural and Technical Stat...
# 282210  North Carolina Agricultural and Technical Stat...
#
#                              Location                               Salary  \
# Job ID
# 354649    Pennsylvania, United States                 Salary Not specified
# 354648    Pennsylvania, United States                 Salary Not specified
# 354561            Utah, United States                 Salary Not specified
# 354411         Alabama, United States  Salary Commensurate with experience
# 354486           Texas, United States                   Competitive Salary
# ...                               ...                                  ...
# 282210  North Carolina, United States                 Salary Not specified
# 282211  North Carolina, United States                 Salary Not specified
# 282211  North Carolina, United States                 Salary Not specified
# 282211  North Carolina, United States                 Salary Not specified
# 282210  North Carolina, United States                 Salary Not specified
#
#        Date Posted                                        Description  \
# Job ID
# 354649  2021-06-29  \n\nCommunity College of Philadelphia\n\n\nGen...
# 354648  2021-06-29  \n\nCommunity College of Philadelphia\n\n\nGen...
# 354561  2021-06-28  \n\n\nInstructor, Developmental English\n\nReq...
# 354411  2021-06-28  \r\n\t\t\t\t\tThe University of Montevallo inv...
# 354486  2021-06-28  \nSOUTHERN METHODIST UNIVERSITY\nAssistant or ...
# ...            ...                                                ...
# 282210  2020-08-15  \r\n\t\t\t\t\tThis Associate Dean for Undergra...
# 282211  2020-08-15  \r\n\t\t\t\t\tThis Associate Dean for Graduate...
# 282211  2020-08-15  \r\n\t\t\t\t\tThis Associate Dean for Graduate...
# 282211  2020-08-15  \r\n\t\t\t\t\tThis Associate Dean for Graduate...
# 282210  2020-08-15  \r\n\t\t\t\t\tThis Associate Dean for Undergra...
#
#         Position Type 0.0      Position Type 0.1  ... Position Type 1.0  \
# Job ID                                            ...
# 354649  Faculty Positions    Professional Fields  ...               NaN
# 354648  Faculty Positions    Professional Fields  ...               NaN
# 354561  Faculty Positions             Humanities  ...               NaN
# 354411  Faculty Positions  Business & Management  ...               NaN
# 354486  Faculty Positions  Business & Management  ...               NaN
# ...                   ...                    ...  ...               ...
# 282210     Administrative        Student Affairs  ...               NaN
# 282211     Administrative       Academic Affairs  ...               NaN
# 282211     Administrative       Academic Affairs  ...               NaN
# 282211     Administrative       Academic Affairs  ...               NaN
# 282210     Administrative        Student Affairs  ...               NaN
#
#        Position Type 1.1 Position Type 1.2 Position Type 1.3  \
# Job ID
# 354649               NaN               NaN               NaN
# 354648               NaN               NaN               NaN
# 354561               NaN               NaN               NaN
# 354411               NaN               NaN               NaN
# 354486               NaN               NaN               NaN
# ...                  ...               ...               ...
# 282210               NaN               NaN               NaN
# 282211               NaN               NaN               NaN
# 282211               NaN               NaN               NaN
# 282211               NaN               NaN               NaN
# 282210               NaN               NaN               NaN
#
#        Position Type 1.4 Position Type 1.5 Position Type 1.6  \
# Job ID
# 354649               NaN               NaN               NaN
# 354648               NaN               NaN               NaN
# 354561               NaN               NaN               NaN
# 354411               NaN               NaN               NaN
# 354486               NaN               NaN               NaN
# ...                  ...               ...               ...
# 282210               NaN               NaN               NaN
# 282211               NaN               NaN               NaN
# 282211               NaN               NaN               NaN
# 282211               NaN               NaN               NaN
# 282210               NaN               NaN               NaN
#
#        Position Type 1.7 Position Type 1.8 Position Type 1.9
# Job ID
# 354649               NaN               NaN               NaN
# 354648               NaN               NaN               NaN
# 354561               NaN               NaN               NaN
# 354411               NaN               NaN               NaN
# 354486               NaN               NaN               NaN
# ...                  ...               ...               ...
# 282210               NaN               NaN               NaN
# 282211               NaN               NaN               NaN
# 282211               NaN               NaN               NaN
# 282211               NaN               NaN               NaN
# 282210               NaN               NaN               NaN
#
# [905 rows x 28 columns]

# %%
from datetime import datetime

timestamp = datetime.now().strftime("%Y-%m-%d")
merged_df.to_csv(f"../data/{timestamp}-chronicles_of_higher_ed.csv")
